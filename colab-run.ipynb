# %% [markdown]
# <a href="https://colab.research.google.com/github/catchshashank/optimal-nego/blob/main/colab-run.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/catchshashank/optimal-nego.git
# Out:
# Cloning into 'optimal-nego'...
# remote: Enumerating objects: 52, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 52 (delta 14), reused 18 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (52/52), 543.83 KiB | 5.61 MiB/s, done.
# Resolving deltas: 100% (14/14), done.

# %%
# !python /content/optimal-nego/stage1/stage1_sst_embedding.py
# Out:
# ...
# STAGE 1: SST EMBEDDING PIPELINE
# ...
#
# [Step 1] Loading data and filtering backchannels...
# Traceback (most recent call last):
#   File "/content/optimal-nego/stage1/stage1_sst_embedding.py", line 436, in <module>
#     df_embedded, dim_table = main()
#                              ^^^^^^
#   File "/content/optimal-nego/stage1/stage1_sst_embedding.py", line 333, in main
#     df_full, df_sub, df_bc = load_and_filter(DATA_PATH)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/optimal-nego/stage1/stage1_sst_embedding.py", line 125, in load_and_filter
#     df = pd.read_csv(path)
#          ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py", line 1026, in read_csv
#     return _read(filepath_or_buffer, kwds)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py", line 620, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
# ...

# %%
# Correct the data path in the script using sed
# !sed -i 's|/content/data/nego-data-final.csv|/content/optimal-nego/data/nego-data-final.csv|g' /content/optimal-nego/stage1/stage1_sst_embedding.py

# Display the modified line to confirm the change (heuristic check)
# !grep -n "nego-data-final.csv" /content/optimal-nego/stage1/stage1_sst_embedding.py
# Out:
# 34:DATA_PATH   = '/content/optimal-nego/data/nego-data-final.csv'

# %%
# Correct the output saving path in the script using sed
# !sed -i 's|/content/outputs/|/content/optimal-nego/outputs/|g' /content/optimal-nego/stage1/stage1_sst_embedding.py

# Display the modified line to confirm the change (heuristic check)
# !grep -n 'outputs/' /content/optimal-nego/stage1/stage1_sst_embedding.py
# Out:
# 35:OUT_DIR     = '/content/optimal-nego/outputs/'

# %%
# Now that the output path has been corrected, let's re-run the stage 1 script again.
# !python /content/optimal-nego/stage1/stage1_sst_embedding.py
# Out:
# ...
# STAGE 1: SST EMBEDDING PIPELINE
# ...
#
# [Step 1] Loading data and filtering backchannels...
#   Total turns        : 7,565
#   Substantive turns  : 5,802 (76.7%)
#   Backchannels       : 1,763 (23.3%)
#   Conversations      : 178
#
# [Step 2] Assigning buyer/seller roles...
#   Buyer turns  : 2,948
#   Seller turns : 2,854
#   Unknown      : 0
#   Conversations with both roles: 178/178
#
# [Step 3] Building 27-dim GoEmotions semantic space...
#   Embedding matrix shape: 5802 x 27
#   Vocab size (TF-IDF)   : 15,000
#
#   Mean activation per emotion dimension:
#     approval           0.0349  █
#     annoyance          0.0140
#     excitement         0.0137
#     confusion          0.0136
#     desire             0.0130
#     sadness            0.0124
#     optimism           0.0119
#     curiosity          0.0105
#     surprise           0.0101
#     joy                0.0091
#     caring             0.0091
#     gratitude          0.0088
#     disapproval        0.0087
# ...

# %%
# Correct the output saving path in the script using sed
# !sed -i 's|/content/outputs/|/content/optimal-nego/outputs/|g' /content/optimal-nego/stage2/stage2_ssm.py

# Display the modified line to confirm the change (heuristic check)
# !grep -n 'outputs/' /content/optimal-nego/stage2/stage2_ssm.py
# Out:
# 10:OUT = '/content/optimal-nego/outputs/'

# %%
# Correct the data path in the script using sed
# !sed -i 's|/mnt/user-data/uploads/nego-data-final.csv|/content/optimal-nego/data/nego-data-final.csv|g' /content/optimal-nego/stage2/stage2_ssm.py

# Display the modified line to confirm the change (heuristic check)
# !grep -n "nego-data-final.csv" /content/optimal-nego/stage2/stage2_ssm.py
# Out:
# 57:df = pd.read_csv('/content/optimal-nego/data/nego-data-final.csv')

# %%
# Now that the data path has been corrected, let's re-run the stage 2 script.
# !python /content/optimal-nego/stage2/stage2_ssm.py
# Out:
# ...
# STAGE 2: COUPLED SSM ON SST EMOTIONAL TRAJECTORIES
# ...
#
# [Step 1] Building dense emotion trajectories...
#   Sparsity: 91.5%  (Stage 1 was 94.9%)
#   Active dims/turn: 1.96  (Stage 1 was 1.17)
#
# [Step 2] Building coupled buyer-seller observations...
#   178 conversations, obs_dim=46, avg_T=32.6
#
# [Step 3] BIC-based latent dimension selection (k=2,3,4)...
#
#   --- k=2 ---
#     iter   1: ll=-92212.8  Δ=inf
#     iter   2: ll=345688.7  Δ=437901.5
#     iter   3: ll=350000.8  Δ=4312.2
#     iter  11: ll=351975.2  Δ=64.8
#     iter  21: ll=352154.3  Δ=41.6
#     iter  31: ll=355368.8  Δ=20.5
#     iter  41: ll=355418.6  Δ=1.2
#     Converged at iter 48
#   k=2: ll=355423.4  BIC=-709590.3  spectral_r=0.9573
#
#   --- k=3 ---
#     iter   1: ll=-92790.9  Δ=inf
#     iter   2: ll=342683.0  Δ=435473.9
#     iter   3: ll=351122.9  Δ=8439.9
#     iter  11: ll=358711.3  Δ=262.5
#     iter  21: ll=359278.5  Δ=1.4
#     Converged at iter 27
# ...

# %%
# Correct the data path in stage3/stage3_annotation.py
# !sed -i 's|/content/data/nego-data-final.csv|/content/optimal-nego/data/nego-data-final.csv|g' /content/optimal-nego/stage3/stage3_annotation.py
# !sed -i 's|/mnt/user-data/uploads/nego-data-final.csv|/content/optimal-nego/data/nego-data-final.csv|g' /content/optimal-nego/stage3/stage3_annotation.py

# Display the modified line to confirm the change (heuristic check)
# !grep -n "nego-data-final.csv" /content/optimal-nego/stage3/stage3_annotation.py
# Out:
# 45:DATA_PATH = '/content/optimal-nego/data/nego-data-final.csv'

# %%
# Correct the output saving path in stage3/stage3_annotation.py
# !sed -i 's|/content/outputs/|/content/optimal-nego/outputs/|g' /content/optimal-nego/stage3/stage3_annotation.py

# Display the modified line to confirm the change (heuristic check)
# !grep -n 'outputs/' /content/optimal-nego/stage3/stage3_annotation.py
# Out:
# 46:OUT_DIR   = '/content/optimal-nego/outputs/'

# %%
# Now that the data and output paths have been corrected, let's run the stage 3 script.
# !python /content/optimal-nego/stage3/stage3_annotation.py
# Out:
# ...
# STAGE 3: BARGAINING ACT ANNOTATION
# Layer 1: Heddaya et al. (2024)  |  Layer 2: Lee & Ames (2017)
# ...
#
# [Step 1] Annotating bargaining acts across 178 conversations...
#   Total turns annotated : 7,565
#   Substantive turns     : 5,802
#
# [Step 2] Layer 1 — Bargaining act coverage:
#   New Offer      :  819 turns  ( 14.1%)
#   Repeat Offer   :  659 turns  ( 11.4%)
#   Push           :  615 turns  ( 10.6%)
#   Comparison     : 1025 turns  ( 17.7%)
#   Allowance      :  162 turns  (  2.8%)
#   End            :  450 turns  (  7.8%)
#
#   Multi-act turns   :  928 (16.0%)
#   No-act turns      : 3450 (59.5%)
#
# [Step 3] Layer 2 — Push sub-type distribution:
#   push_constraint          :   75 (12.2% of Push turns)
#   push_disparagement       :   17 (2.8% of Push turns)
#   push_neutral             :  523 (85.0% of Push turns)
#
#   Comparison sub-type distribution:
#   comparison_price         :  547 (53.4% of Comparison turns)
# ...

# %%
# Correct the data path in stage3/task3bc.py
# !sed -i 's|/content/data/nego-data-final.csv|/content/optimal-nego/data/nego-data-final.csv|g' /content/optimal-nego/stage3/task3bc.py
# !sed -i 's|/mnt/user-data/uploads/nego-data-final.csv|/content/optimal-nego/data/nego-data-final.csv|g' /content/optimal-nego/stage3/task3bc.py

# Display the modified line to confirm the change (heuristic check)
# !grep -n "nego-data-final.csv" /content/optimal-nego/stage3/task3bc.py

# %%
# Correct the output saving path in stage3/task3bc.py
# !sed -i 's|/mnt/user-data/outputs/|/content/optimal-nego/outputs/|g' /content/optimal-nego/stage3/task3bc.py

# Display the modified line to confirm the change (heuristic check)
# !grep -n 'outputs/' /content/optimal-nego/stage3/task3bc.py
# Out:
# 45:OUT_DIR = '/content/optimal-nego/outputs/'

# %%
# Now that the data and output paths have been corrected, let's run the task3bc.py script.
# !python /content/optimal-nego/stage3/task3bc.py
# Out:
# ...
# TASK 3B: TACTIC × LATENT STATE OVERLAY
# TASK 3C: HORSE RACE REGRESSION
# ...
#
# Merged dataset: (5802, 25)
# Conversations: 178
# Sale rate: 59.0%
#
# ─────────────────────────────────────────────────────────────────
# TASK 3B — Tactic → Latent State Shift (z_t → z_{t+1})
# ─────────────────────────────────────────────────────────────────
#
#   Mean shift in dominant z-dimension per act:
#   Act                           N  Dom dim  Mean shift       z_t     z_t+1
#   --------------------------------------------------------------------
#   push_disparagement           17      z_1   -0.18813↓  -1.22298  -1.41111
#   comparison_mixed            183      z_4   -0.12719↓  -0.17063  -0.29782
#   push_constraint              74      z_3   +0.08661↑  -0.02855   0.05805
#   allowance                   153      z_3   -0.06329↓  -0.37000  -0.43329
#   comparison_quality          295      z_4   -0.05940↓  -0.11221  -0.17161
# ...

# %%
# Change to the optimal-nego directory
# %cd /content/optimal-nego/
# Out:
# /content/optimal-nego

# %%
# Set your Git user name and email (replace with your actual info)
# !git config --global user.email "shashank.dubey@hec.edu"
# !git config --global user.name "https://github.com/catchshashank"

# %%
# Retrieve your GitHub token from Colab secrets
from google.colab import userdata
GITHUB_TOKEN = userdata.get('GITHUB_API_KEY')

# Construct the push URL with the token for authentication
# This assumes your repository is 'https://github.com/catchshashank/optimal-nego.git'
# If your repository is different, please update the URL accordingly.
# !git remote set-url origin https://oauth2:$GITHUB_TOKEN@github.com/catchshashank/optimal-nego.git

# %% [markdown]
# Now that Git is configured with your authentication token, you can add, commit, and push your changes.

# %%
# Add all changes (including new output files) to the staging area
# !git add outputs/

# Commit the changes
# !git commit -m "Add generated output files from Colab run"
# Out:
# [main 6adc0a3] Add generated output files from Colab run
#  15 files changed, 27430 insertions(+)
#  create mode 100644 outputs/stage1_backchannels.csv
#  create mode 100644 outputs/stage1_diagnostics.txt
#  create mode 100644 outputs/stage1_sst_dimensions.csv
#  create mode 100644 outputs/stage1_turns_embedded.csv
#  create mode 100644 outputs/stage2_diagnostics.txt
#  create mode 100644 outputs/stage2_latent_states.csv
#  create mode 100644 outputs/stage2_outcome_prediction.csv
#  create mode 100644 outputs/stage2_ssm_params.npz
#  create mode 100644 outputs/stage2_trajectories.csv
#  create mode 100644 outputs/stage3_annotated.csv
#  create mode 100644 outputs/stage3_diagnostics.txt
#  create mode 100644 outputs/task3b_tactic_shifts.csv
#  create mode 100644 outputs/task3bc_diagnostics.txt
#  create mode 100644 outputs/task3c_features.csv
#  create mode 100644 outputs/task3c_horse_race.csv

# %%
# Add the modified Python scripts to the staging area
# !git add stage1/stage1_sst_embedding.py
# !git add stage2/stage2_ssm.py
# !git add stage3/stage3_annotation.py
# !git add stage3/task3bc.py

# Commit the changes to the Python scripts
# !git commit -m "Correct data and output paths in Python scripts"
# Out:
# [main 26ef07a] Correct data and output paths in Python scripts
#  4 files changed, 7 insertions(+), 7 deletions(-)

# %%
# Configure git to rebase when pulling to resolve divergent branches
# !git config pull.rebase true

# Pull the latest changes from the remote repository, using the rebase strategy
# !git pull origin main

# Push the committed changes to the main branch
# !git push origin main
# Out:
# From https://github.com/catchshashank/optimal-nego
#  * branch            main       -> FETCH_HEAD
# Successfully rebased and updated refs/heads/main.
# Enumerating objects: 34, done.
# Counting objects: 100% (34/34), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (25/25), done.
# Writing objects: 100% (25/25), 648.94 KiB | 2.48 MiB/s, done.
# Total 25 (delta 10), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (10/10), completed with 8 local objects.
# To https://github.com/catchshashank/optimal-nego.git
#    c5e62f5..5efeeca  main -> main
